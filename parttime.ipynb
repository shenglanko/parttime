# %% [markdown]
# - In a project I helped a master student to complete her project about portfolio management, CAPM, and multiple factor models:
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %% [markdown]
# - My script for proving a protocol based on Chinese Remainder Theorem is user-irrepressible in a tutorial project:
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %% [markdown]
# -	In this tutorial project I teach vector calculus with the help of MATLAB:
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %% [markdown]
# -	In this tutorial project I teach a postgraduate student on her research project on cosmology:
# <div>
# <img src="attachment:image.png" width="300"/>
# </div>

# %% [markdown]
# -	In this project I helped a postgraduate student understand the proof of the identity involved in partitioning an integer:
# <div>
# <img src="attachment:image.png" width="200"/>
# </div>

# %% [markdown]
# - In my free time, I create PE ratio river diagram and other interactive __dashboards__ for my own portfolio:
# ![image.png](attachment:image.png)

# %% [markdown]
# <div>
# <img src="attachment:image-2.png" width="500"/>
# </div>

# %% [markdown]
# - In this project I demonstrate the application of __Reinforcement Learning__ to solve a maze puzzle:
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# - In this project, we demonstrate that it is possible to detect the grocery shopping behaviour change (as a proxy of __life stage change__):
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# - In this project, I explored a innovative clustering algorithm rooted in physics known as __dynamic quantum clustering__:
# <img src="DQC_demo.gif" width="550" align="center">
